# %% [markdown]
# ## Import libraries and load data

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
import torch.nn as nn
import torch
import pandas as pd
import sys
from torch.utils.data import DataLoader

# %%
device="cuda" if torch.cuda.is_available() else "cpu"
print(device)

out = np.load('disc-benchmark-files/training-data.npz')
th_train = out['th'] #th[0],th[1],th[2],th[3],...
u_train = out['u'] #u[0],u[1],u[2],u[3],...

data = np.load('disc-benchmark-files/test-simulation-submission-file.npz')
u_test = data['u']
th_test = data['th'] #only the first 50 values are filled the rest are zeros

u_test_sim = [torch.as_tensor(x).to(device=device, dtype=torch.float32) for x in [u_test[0:50]]][0].squeeze()
th_test_sim = [torch.as_tensor(x).to(device=device, dtype=torch.float32) for x in [th_test[0:50]]][0].squeeze()
# Out:
# cuda

# %% [markdown]
# ## Visualize data

# %%
# Plotting the data
plt.figure(figsize=(20,4))
plt.subplot(1,2,1)
plt.plot(u_train,th_train,'.')
plt.xlabel('input (V)')
plt.ylabel('output (radians)')
plt.title('Training Data')
plt.subplot(1,2,2)
plt.plot(th_test,th_test,'.')
plt.xlabel('input (V)')
plt.ylabel('output (radians)')
plt.title('Test Data')
plt.show()

# %% [markdown]
# ## 1. ANN

# %%
def create_IO_data(u,y,na,nb):
    X = []
    Y = []
    for k in range(max(na,nb), len(y)):
        X.append(np.concatenate([u[k-nb:k],y[k-na:k]]))
        Y.append(y[k])
    return np.array(X), np.array(Y)

# %%
# class Network(nn.Module):
#     def __init__(self, n_in, n_hidden_nodes):
#         super(Network,self).__init__()
#         self.lay1 = nn.Linear(n_in,n_hidden_nodes)
#         self.lay2 = nn.Linear(n_hidden_nodes,n_hidden_nodes)
#         self.lay3 = nn.Linear(n_hidden_nodes,1)
#     def forward(self,x):
#         x1 = torch.relu(self.lay1(x))
#         x2 = torch.relu(self.lay2(x1))
#         y = self.lay3(x2)
#         return y

# class Network(nn.Module):
#     def __init__(self, n_in, n_hidden_nodes):
#         super(Network,self).__init__()
#         self.lay1 = nn.Linear(n_in,n_hidden_nodes)
#         self.lay2 = nn.Linear(n_hidden_nodes,1)
#     def forward(self,x):
#         x1 = torch.relu(self.lay1(x))
#         y = self.lay2(x1)[:,0]
#         return y

# %%
# 3 layers
class Network(nn.Module):
    def __init__(self, n_in, n_hidden_nodes):
        super(Network,self).__init__()
        self.lay1 = nn.Linear(n_in,n_hidden_nodes)
        self.lay2 = nn.Linear(n_hidden_nodes,64)
        self.lay3 = nn.Linear(64,32)
        self.lay4 = nn.Linear(32,1)
        # self.dropout = nn.Dropout(0.5)

    def forward(self,x):
        x1 = torch.relu(self.lay1(x))

        x2 = torch.relu(self.lay2(x1))

        x3 = torch.relu(self.lay3(x2))
        # x3 = self.dropout(x3)

        y = self.lay4(x3)[:,0]
        return y

# %%
def RMS_NRMS(y_pred, y_truth):
    y_pred = y_pred.detach().cpu()
    y_truth = y_truth.detach().cpu()
    RMS = (torch.mean((y_pred-y_truth)**2))**0.5
    NRMS = RMS/torch.std(y_truth)
    return RMS, NRMS

# %%
class Trainer:
    def __init__(self, model, data):
        self.device = "cuda" if torch.cuda.is_available() else "cpu"
        self.model = model.to(self.device)
        self.data = data

        self.optimizer = torch.optim.Adam(self.model.parameters(),lr=1e-4)
        self.critereon = nn.MSELoss()

        assert self.critereon is not None, "You have not defined a loss"
        assert self.optimizer is not None, "You have not defined an optimizer"


    def train_epoch(self, inputs, truths):
            # Put the model in training mode
            self.model.train()

            # Store each step's accuracy and loss for this epoch
            epoch_metrics = {
                "loss": [],
                "RMS": [],
                "NRMS": []
            }

            # Zero the gradients from the previous step
            self.optimizer.zero_grad()

            # Move the inputs and truths to the target device
            inputs = inputs.to(device=self.device)
            truths = truths.to(device=self.device)

            # Run model on the inputs
            output = self.model(inputs)

            # Perform backpropagation
            loss = self.critereon(output, truths)
            loss.backward()
            self.optimizer.step()

            # Store the metrics of this step
            step_metrics = {
                'loss': loss.item(),
                'RMS': RMS_NRMS(output, truths)[0],
                'NRMS': RMS_NRMS(output, truths)[1]
            }

            # Add to epoch's metrics
            for k,v in step_metrics.items():
                epoch_metrics[k].append(v)

            # Return metrics
            return epoch_metrics

    def val_epoch(self, inputs, truths):
        epoch_metrics = {
                "loss": [],
                "RMS": [],
                "NRMS": []
            }

        # Put the model in evaluation mode
        self.model.eval()
        with torch.no_grad():
            # Move the inputs and truths to the target device
            inputs = inputs.to(device=self.device, dtype=torch.float32)
            truths = truths.to(device=self.device, dtype=torch.float32)

            # Run model on the inputs
            output = self.model(inputs)
            loss = self.critereon(output, truths)

            # Store the metrics of this step
            step_metrics = {
                'loss': loss.item(),
                'RMS': RMS_NRMS(output, truths)[0],
                'NRMS': RMS_NRMS(output, truths)[1]
            }

            # Add to epoch's metrics
            for k,v in step_metrics.items():
                epoch_metrics[k].append(v)

        # Return metrics
        return epoch_metrics

    # def fit(self, epochs: int):
    #     # Store metrics of the training process (plot this to gain insight)
    #     df_train = pd.DataFrame()
    #     df_val = pd.DataFrame()

    #     # Train the model for the provided amount of epochs
    #     for epoch in range(1, epochs+1):
    #         # print(f'Epoch {epoch}')

    #         metrics_train = self.train_epoch(self.data["Xtrain"],self.data["Ytrain"])
    #         df_train = pd.concat([df_train,pd.DataFrame({'epoch': [epoch for _ in range(len(metrics_train["loss"]))], **metrics_train})], ignore_index=True)

    #         metrics_val = self.val_epoch(self.data["Xval"],self.data["Yval"])
    #         df_val = pd.concat([df_val,pd.DataFrame({'epoch': [epoch for _ in range(len(metrics_val["loss"]))], **metrics_val})], ignore_index=True)
    #         # print(metrics_train["loss"])
    #         loss_train = metrics_train["loss"]
    #         loss_val = metrics_val["loss"]
    #         RMS_val = metrics_val["RMS"]
    #         NRMS_val = metrics_val["NRMS"]

    #         if (epoch + 1) % 5000 == 0:
    #             print('epoch =', epoch+1, 'Train_loss =',loss_train, 'Val_loss =', loss_val, 'Val_RMS =', RMS_val, 'Val_NRMS =', NRMS_val)

    #     # Return a dataframe that logs the training process. This can be exported to a CSV or plotted directly.
    #     return df_train, df_val

    '''mini batch'''
    def fit(self, epochs: int, batch_size: int):
        df_train = pd.DataFrame()
        df_val = pd.DataFrame()
        num_samples = len(self.data["Xtrain"])
        num_batches = num_samples // batch_size

        for epoch in range(1, epochs+1):
            for batch in range(num_batches):
                start_idx = batch * batch_size
                end_idx = (batch + 1) * batch_size

                batch_X = self.data["Xtrain"][start_idx:end_idx]
                batch_Y = self.data["Ytrain"][start_idx:end_idx]

                metrics_train = self.train_epoch(batch_X, batch_Y)
                df_train = pd.concat([df_train, pd.DataFrame({'epoch': [epoch for _ in range(len(metrics_train["loss"]))], **metrics_train})], ignore_index=True)

                metrics_val = self.val_epoch(self.data["Xval"], self.data["Yval"])
                df_val = pd.concat([df_val, pd.DataFrame({'epoch': [epoch for _ in range(len(metrics_val["loss"]))], **metrics_val})], ignore_index=True)

                loss_train = metrics_train["loss"]
                loss_val = metrics_val["loss"]
                RMS_val = metrics_val["RMS"]
                NRMS_val = metrics_val["NRMS"]

            if (epoch + 1) % 5000 == 0:
                print('epoch =', epoch+1, 'Train_loss =', loss_train, 'Val_loss =', loss_val, 'Val_RMS =', RMS_val, 'Val_NRMS =', NRMS_val)

        return df_train, df_val

# %% [markdown]
# ## tunning

# %%
import random

list1 = range(0, 15)
list2 = range(0, 15)
results = []

# using random layout near origin good selection
while len(results) < 30:
    # select randomly
    num1 = random.choice(list1)
    num2 = random.choice(list2)
    if num1==0&num2==0:
        continue
    result = (num1, num2)

    # if it is not selected, add it
    if result not in results:
        results.append(result)
print(results)
# Out:
# [(6, 6), (7, 9), (6, 11), (11, 12), (11, 5), (6, 5), (9, 12), (11, 4), (3, 4), (10, 4), (10, 9), (13, 6), (2, 4), (12, 6), (6, 8), (4, 2), (10, 12), (4, 5), (5, 2), (5, 8), (7, 7), (13, 13), (2, 1), (3, 8), (13, 4), (9, 4), (4, 1), (11, 10), (5, 1), (5, 7)]

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

loss = []
RMS = []
NRMS = []

for i in range(len(results)):
    val_RMS = []
    val_NRMS = []
    val_Loss = []
    na, nb = results[i]

    # generate data
    Xdata, Ydata = create_IO_data(u_train, th_train, na, nb)  # For training data
    Xtrain, Xval, Ytrain, Yval = train_test_split(Xdata,Ydata)
    Xtrain, Xval, Ytrain, Yval = [torch.as_tensor(x).to(device=device, dtype=torch.float32) for x in [Xtrain, Xval, Ytrain, Yval]]

    data = {
        "Xtrain": Xtrain,
        "Xval": Xval,
        "Ytrain": Ytrain,
        "Yval": Yval
    }

    # free memory
    torch.cuda.empty_cache()

    # Train the passthrough network
    print("Testing training process: ", i, f'(na = {results[i][0]}, nb = {results[i][1]})')
    model = Network(na+nb, n_hidden_nodes = 64)

    epochs = 20000
    trainer = Trainer(model, data)
    train_resluts, validation_results = trainer.fit(epochs=epochs, batch_size=29500)

    # save loss, RMS, NRMS
    painted = 'loss'
    for j in range(1,validation_results['epoch'].max()):
        val_Loss.append(validation_results[validation_results['epoch']==j][painted].mean(0))
    loss.append(val_Loss)

    painted = 'RMS'
    for i in range(1,validation_results['epoch'].max()):
        val_RMS.append(validation_results[validation_results['epoch']==i][painted].mean(0))
    RMS.append(val_RMS)

    painted = 'NRMS'
    for k in range(1,validation_results['epoch'].max()):
        val_NRMS.append(validation_results[validation_results['epoch']==k][painted].mean(0))
    NRMS.append(val_NRMS)
# Out:
# Testing training process:  0 (na = 6, nb = 6)
# epoch = 5000 Train_loss = [4.0888466173782945e-05] Val_loss = [4.700426507042721e-05] Val_RMS = [tensor(0.0069)] Val_NRMS = [tensor(0.0140)]
# epoch = 10000 Train_loss = [1.5371948393294588e-05] Val_loss = [1.6346932170563377e-05] Val_RMS = [tensor(0.0040)] Val_NRMS = [tensor(0.0082)]
# epoch = 15000 Train_loss = [1.1170714969921391e-05] Val_loss = [1.1837225429189857e-05] Val_RMS = [tensor(0.0034)] Val_NRMS = [tensor(0.0070)]
# epoch = 20000 Train_loss = [9.625600796425715e-06] Val_loss = [1.014098415907938e-05] Val_RMS = [tensor(0.0032)] Val_NRMS = [tensor(0.0065)]
# Testing training process:  1 (na = 7, nb = 9)
# epoch = 5000 Train_loss = [4.061974323121831e-05] Val_loss = [5.062222044216469e-05] Val_RMS = [tensor(0.0071)] Val_NRMS = [tensor(0.0145)]
# epoch = 10000 Train_loss = [1.0333274985896423e-05] Val_loss = [1.3637351003126241e-05] Val_RMS = [tensor(0.0037)] Val_NRMS = [tensor(0.0076)]
# epoch = 15000 Train_loss = [7.178554369602352e-06] Val_loss = [9.950386811397038e-06] Val_RMS = [tensor(0.0032)] Val_NRMS = [tensor(0.0064)]
# epoch = 20000 Train_loss = [7.273498795257183e-06] Val_loss = [9.395637789566536e-06] Val_RMS = [tensor(0.0031)] Val_NRMS = [tensor(0.0063)]
# Testing training process:  2 (na = 6, nb = 11)
# epoch = 5000 Train_loss = [4.1701525333337486e-05] Val_loss = [5.308253093971871e-05] Val_RMS = [tensor(0.0073)] Val_NRMS = [tensor(0.0148)]
# epoch = 10000 Train_loss = [1.0017141903517768e-05] Val_loss = [1.2016448636131827e-05] Val_RMS = [tensor(0.0035)] Val_NRMS = [tensor(0.0070)]
# epoch = 15000 Train_loss = [7.3203941610699985e-06] Val_loss = [8.866848475008737e-06] Val_RMS = [tensor(0.0030)] Val_NRMS = [tensor(0.0060)]
# epoch = 20000 Train_loss = [6.375303655659081e-06] Val_loss = [7.5038619797851425e-06] Val_RMS = [tensor(0.0027)] Val_NRMS = [tensor(0.0056)]
# Testing training process:  3 (na = 11, nb = 12)
# epoch = 5000 Train_loss = [2.1550442397710867e-05] Val_loss = [3.107974407612346e-05] Val_RMS = [tensor(0.0056)] Val_NRMS = [tensor(0.0113)]
# epoch = 10000 Train_loss = [8.041854925977532e-06] Val_loss = [1.2174394214525819e-05] Val_RMS = [tensor(0.0035)] Val_NRMS = [tensor(0.0071)]
# epoch = 15000 Train_loss = [6.747676252416568e-06] Val_loss = [1.0421812476124614e-05] Val_RMS = [tensor(0.0032)] Val_NRMS = [tensor(0.0066)]
# epoch = 20000 Train_loss = [6.192542514327215e-06] Val_loss = [9.822291758609936e-06] Val_RMS = [tensor(0.0031)] Val_NRMS = [tensor(0.0064)]
# Testing training process:  4 (na = 11, nb = 5)
# epoch = 5000 Train_loss = [3.005649705301039e-05] Val_loss = [3.767042653635144e-05] Val_RMS = [tensor(0.0061)] Val_NRMS = [tensor(0.0126)]
# epoch = 10000 Train_loss = [1.2492217138060369e-05] Val_loss = [1.5794939827173948e-05] Val_RMS = [tensor(0.0040)] Val_NRMS = [tensor(0.0081)]
# epoch = 15000 Train_loss = [9.116154615185224e-06] Val_loss = [1.1797230399679393e-05] Val_RMS = [tensor(0.0034)] Val_NRMS = [tensor(0.0070)]
# epoch = 20000 Train_loss = [8.032699042814784e-06] Val_loss = [1.0508358172955923e-05] Val_RMS = [tensor(0.0032)] Val_NRMS = [tensor(0.0066)]
# Testing training process:  5 (na = 6, nb = 5)
# epoch = 5000 Train_loss = [4.532207822194323e-05] Val_loss = [5.137981861480512e-05] Val_RMS = [tensor(0.0072)] Val_NRMS = [tensor(0.0148)]
# epoch = 10000 Train_loss = [1.7333466530544683e-05] Val_loss = [1.9331009752932005e-05] Val_RMS = [tensor(0.0044)] Val_NRMS = [tensor(0.0091)]
# epoch = 15000 Train_loss = [1.1790063581429422e-05] Val_loss = [1.3202474292484112e-05] Val_RMS = [tensor(0.0036)] Val_NRMS = [tensor(0.0075)]
# epoch = 20000 Train_loss = [9.324420716438908e-06] Val_loss = [1.053051255439641e-05] Val_RMS = [tensor(0.0032)] Val_NRMS = [tensor(0.0067)]
# Testing training process:  6 (na = 9, nb = 12)
# epoch = 5000 Train_loss = [2.0823268641834147e-05] Val_loss = [2.483987555024214e-05] Val_RMS = [tensor(0.0050)] Val_NRMS = [tensor(0.0102)]
# epoch = 10000 Train_loss = [7.653661668882705e-06] Val_loss = [9.35614025365794e-06] Val_RMS = [tensor(0.0031)] Val_NRMS = [tensor(0.0062)]
# epoch = 15000 Train_loss = [6.643895176239312e-06] Val_loss = [8.123507541313302e-06] Val_RMS = [tensor(0.0029)] Val_NRMS = [tensor(0.0058)]
# epoch = 20000 Train_loss = [6.238976766326232e-06] Val_loss = [7.752569217700511e-06] Val_RMS = [tensor(0.0028)] Val_NRMS = [tensor(0.0057)]
# Testing training process:  7 (na = 11, nb = 4)
# epoch = 5000 Train_loss = [3.688201104523614e-05] Val_loss = [4.3713898776331916e-05] Val_RMS = [tensor(0.0066)] Val_NRMS = [tensor(0.0134)]
# epoch = 10000 Train_loss = [1.4678160368930548e-05] Val_loss = [1.8000995623879135e-05] Val_RMS = [tensor(0.0042)] Val_NRMS = [tensor(0.0086)]
# epoch = 15000 Train_loss = [1.0457578355271835e-05] Val_loss = [1.3507307812687941e-05] Val_RMS = [tensor(0.0037)] Val_NRMS = [tensor(0.0074)]
# epoch = 20000 Train_loss = [9.750305252964608e-06] Val_loss = [1.2430097740434576e-05] Val_RMS = [tensor(0.0035)] Val_NRMS = [tensor(0.0071)]
# Testing training process:  8 (na = 3, nb = 4)
# epoch = 5000 Train_loss = [4.1668765334179625e-05] Val_loss = [4.637129313778132e-05] Val_RMS = [tensor(0.0068)] Val_NRMS = [tensor(0.0139)]
# epoch = 10000 Train_loss = [2.5452553018112667e-05] Val_loss = [2.825387127813883e-05] Val_RMS = [tensor(0.0053)] Val_NRMS = [tensor(0.0109)]
# epoch = 15000 Train_loss = [2.053505704679992e-05] Val_loss = [2.2816097043687478e-05] Val_RMS = [tensor(0.0048)] Val_NRMS = [tensor(0.0098)]
# epoch = 20000 Train_loss = [2.010751086345408e-05] Val_loss = [2.2454698410001583e-05] Val_RMS = [tensor(0.0047)] Val_NRMS = [tensor(0.0097)]
# Testing training process:  9 (na = 10, nb = 4)
# epoch = 5000 Train_loss = [3.536324220476672e-05] Val_loss = [3.899926014128141e-05] Val_RMS = [tensor(0.0062)] Val_NRMS = [tensor(0.0128)]
# epoch = 10000 Train_loss = [1.466779394831974e-05] Val_loss = [1.6836071154102683e-05] Val_RMS = [tensor(0.0041)] Val_NRMS = [tensor(0.0084)]
# epoch = 15000 Train_loss = [1.6974634490907192e-05] Val_loss = [1.722139677440282e-05] Val_RMS = [tensor(0.0041)] Val_NRMS = [tensor(0.0085)]
# epoch = 20000 Train_loss = [9.194515769195277e-06] Val_loss = [1.0842280062206555e-05] Val_RMS = [tensor(0.0033)] Val_NRMS = [tensor(0.0068)]
# Testing training process:  10 (na = 10, nb = 9)
# epoch = 5000 Train_loss = [2.786508593999315e-05] Val_loss = [3.612920772866346e-05] Val_RMS = [tensor(0.0060)] Val_NRMS = [tensor(0.0123)]
# epoch = 10000 Train_loss = [8.71532301971456e-06] Val_loss = [1.2358889762253966e-05] Val_RMS = [tensor(0.0035)] Val_NRMS = [tensor(0.0072)]
# epoch = 15000 Train_loss = [6.728279458911857e-06] Val_loss = [9.917090210365131e-06] Val_RMS = [tensor(0.0031)] Val_NRMS = [tensor(0.0064)]
# epoch = 20000 Train_loss = [6.05044670010102e-06] Val_loss = [9.066880920727272e-06] Val_RMS = [tensor(0.0030)] Val_NRMS = [tensor(0.0061)]
# Testing training process:  11 (na = 13, nb = 6)
# epoch = 5000 Train_loss = [3.518309677019715e-05] Val_loss = [3.874198591802269e-05] Val_RMS = [tensor(0.0062)] Val_NRMS = [tensor(0.0127)]
# epoch = 10000 Train_loss = [1.102391706808703e-05] Val_loss = [1.3197365660744254e-05] Val_RMS = [tensor(0.0036)] Val_NRMS = [tensor(0.0074)]
# epoch = 15000 Train_loss = [8.262218216259498e-06] Val_loss = [1.0217396265943535e-05] Val_RMS = [tensor(0.0032)] Val_NRMS = [tensor(0.0065)]
# epoch = 20000 Train_loss = [8.03900184109807e-06] Val_loss = [9.754292477737181e-06] Val_RMS = [tensor(0.0031)] Val_NRMS = [tensor(0.0064)]
# Testing training process:  12 (na = 2, nb = 4)
# epoch = 5000 Train_loss = [4.419428660185076e-05] Val_loss = [4.9323240091325715e-05] Val_RMS = [tensor(0.0070)] Val_NRMS = [tensor(0.0143)]
# epoch = 10000 Train_loss = [2.6947856895276345e-05] Val_loss = [3.076810025959276e-05] Val_RMS = [tensor(0.0055)] Val_NRMS = [tensor(0.0113)]
# epoch = 15000 Train_loss = [2.305199086549692e-05] Val_loss = [2.6784960937220603e-05] Val_RMS = [tensor(0.0052)] Val_NRMS = [tensor(0.0105)]
# epoch = 20000 Train_loss = [2.1624706278089434e-05] Val_loss = [2.536572537792381e-05] Val_RMS = [tensor(0.0050)] Val_NRMS = [tensor(0.0102)]
# Testing training process:  13 (na = 12, nb = 6)
# epoch = 5000 Train_loss = [3.877449125866406e-05] Val_loss = [4.833760976907797e-05] Val_RMS = [tensor(0.0070)] Val_NRMS = [tensor(0.0141)]
# epoch = 10000 Train_loss = [1.3123180906404741e-05] Val_loss = [1.743919710861519e-05] Val_RMS = [tensor(0.0042)] Val_NRMS = [tensor(0.0085)]
# epoch = 15000 Train_loss = [9.310931091022212e-06] Val_loss = [1.3227771887613926e-05] Val_RMS = [tensor(0.0036)] Val_NRMS = [tensor(0.0074)]
# epoch = 20000 Train_loss = [7.530995389970485e-06] Val_loss = [1.1157996596011799e-05] Val_RMS = [tensor(0.0033)] Val_NRMS = [tensor(0.0068)]
# Testing training process:  14 (na = 6, nb = 8)
# epoch = 5000 Train_loss = [4.47440761490725e-05] Val_loss = [4.995870767743327e-05] Val_RMS = [tensor(0.0071)] Val_NRMS = [tensor(0.0145)]
# epoch = 10000 Train_loss = [1.2445858374121599e-05] Val_loss = [1.3522130757337436e-05] Val_RMS = [tensor(0.0037)] Val_NRMS = [tensor(0.0075)]
# epoch = 15000 Train_loss = [8.518413778801914e-06] Val_loss = [9.498582585365511e-06] Val_RMS = [tensor(0.0031)] Val_NRMS = [tensor(0.0063)]
# epoch = 20000 Train_loss = [8.464575330435764e-06] Val_loss = [9.329821295978036e-06] Val_RMS = [tensor(0.0031)] Val_NRMS = [tensor(0.0063)]
# Testing training process:  15 (na = 4, nb = 2)
# epoch = 5000 Train_loss = [2.996625698870048e-05] Val_loss = [3.239191210013814e-05] Val_RMS = [tensor(0.0057)] Val_NRMS = [tensor(0.0116)]
# epoch = 10000 Train_loss = [1.841757148213219e-05] Val_loss = [2.000632775889244e-05] Val_RMS = [tensor(0.0045)] Val_NRMS = [tensor(0.0091)]
# epoch = 15000 Train_loss = [1.5327275832532905e-05] Val_loss = [1.6714946468709968e-05] Val_RMS = [tensor(0.0041)] Val_NRMS = [tensor(0.0083)]
# epoch = 20000 Train_loss = [1.4297213965619449e-05] Val_loss = [1.54435165313771e-05] Val_RMS = [tensor(0.0039)] Val_NRMS = [tensor(0.0080)]
# Testing training process:  16 (na = 10, nb = 12)
# epoch = 5000 Train_loss = [2.5412979084649123e-05] Val_loss = [2.9603605071315542e-05] Val_RMS = [tensor(0.0054)] Val_NRMS = [tensor(0.0111)]
# epoch = 10000 Train_loss = [9.639511517889332e-06] Val_loss = [1.2058534593961667e-05] Val_RMS = [tensor(0.0035)] Val_NRMS = [tensor(0.0071)]
# epoch = 15000 Train_loss = [7.180366992542986e-06] Val_loss = [8.884518138074782e-06] Val_RMS = [tensor(0.0030)] Val_NRMS = [tensor(0.0061)]
# epoch = 20000 Train_loss = [6.4786368056957144e-06] Val_loss = [8.036770850594621e-06] Val_RMS = [tensor(0.0028)] Val_NRMS = [tensor(0.0058)]
# Testing training process:  17 (na = 4, nb = 5)
# epoch = 5000 Train_loss = [4.349650407675654e-05] Val_loss = [5.1301150961080566e-05] Val_RMS = [tensor(0.0072)] Val_NRMS = [tensor(0.0146)]
# epoch = 10000 Train_loss = [2.056573430309072e-05] Val_loss = [2.4761287932051346e-05] Val_RMS = [tensor(0.0050)] Val_NRMS = [tensor(0.0102)]
# epoch = 15000 Train_loss = [1.6504773157066666e-05] Val_loss = [1.9862072804244235e-05] Val_RMS = [tensor(0.0045)] Val_NRMS = [tensor(0.0091)]
# epoch = 20000 Train_loss = [1.3511004908650648e-05] Val_loss = [1.5695468391641043e-05] Val_RMS = [tensor(0.0040)] Val_NRMS = [tensor(0.0081)]
# Testing training process:  18 (na = 5, nb = 2)
# epoch = 5000 Train_loss = [3.3980453736148775e-05] Val_loss = [3.951996404794045e-05] Val_RMS = [tensor(0.0063)] Val_NRMS = [tensor(0.0128)]
# epoch = 10000 Train_loss = [1.9342802261235192e-05] Val_loss = [2.1588939489447512e-05] Val_RMS = [tensor(0.0046)] Val_NRMS = [tensor(0.0095)]
# epoch = 15000 Train_loss = [1.6257994502666406e-05] Val_loss = [1.8236449250252917e-05] Val_RMS = [tensor(0.0043)] Val_NRMS = [tensor(0.0087)]
# epoch = 20000 Train_loss = [1.5369074390036985e-05] Val_loss = [1.628133759368211e-05] Val_RMS = [tensor(0.0040)] Val_NRMS = [tensor(0.0082)]
# Testing training process:  19 (na = 5, nb = 8)
# epoch = 5000 Train_loss = [4.321958840591833e-05] Val_loss = [5.0113296310883015e-05] Val_RMS = [tensor(0.0071)] Val_NRMS = [tensor(0.0143)]
# epoch = 10000 Train_loss = [1.8391941921436228e-05] Val_loss = [2.0713088815682568e-05] Val_RMS = [tensor(0.0046)] Val_NRMS = [tensor(0.0092)]
# epoch = 15000 Train_loss = [1.0762355486804154e-05] Val_loss = [1.2012039405817632e-05] Val_RMS = [tensor(0.0035)] Val_NRMS = [tensor(0.0070)]
# epoch = 20000 Train_loss = [8.947043170337565e-06] Val_loss = [1.012961638480192e-05] Val_RMS = [tensor(0.0032)] Val_NRMS = [tensor(0.0064)]
# Testing training process:  20 (na = 7, nb = 7)
# epoch = 5000 Train_loss = [5.423411130323075e-05] Val_loss = [6.484671030193567e-05] Val_RMS = [tensor(0.0081)] Val_NRMS = [tensor(0.0165)]
# epoch = 10000 Train_loss = [1.499199333920842e-05] Val_loss = [1.8262897356180474e-05] Val_RMS = [tensor(0.0043)] Val_NRMS = [tensor(0.0087)]
# epoch = 15000 Train_loss = [1.071216775017092e-05] Val_loss = [1.2622549547813833e-05] Val_RMS = [tensor(0.0036)] Val_NRMS = [tensor(0.0073)]
# epoch = 20000 Train_loss = [9.318998309026938e-06] Val_loss = [1.082600556401303e-05] Val_RMS = [tensor(0.0033)] Val_NRMS = [tensor(0.0067)]
# Testing training process:  21 (na = 13, nb = 13)
# epoch = 5000 Train_loss = [2.5455368813709356e-05] Val_loss = [3.600308991735801e-05] Val_RMS = [tensor(0.0060)] Val_NRMS = [tensor(0.0123)]
# epoch = 10000 Train_loss = [8.211209205910563e-06] Val_loss = [1.1539971637830604e-05] Val_RMS = [tensor(0.0034)] Val_NRMS = [tensor(0.0069)]
# epoch = 15000 Train_loss = [6.0517736528709065e-06] Val_loss = [9.339439202449284e-06] Val_RMS = [tensor(0.0031)] Val_NRMS = [tensor(0.0062)]
# epoch = 20000 Train_loss = [5.532803243113449e-06] Val_loss = [8.858502951625269e-06] Val_RMS = [tensor(0.0030)] Val_NRMS = [tensor(0.0061)]
# Testing training process:  22 (na = 2, nb = 1)
# epoch = 5000 Train_loss = [0.00012158631579950452] Val_loss = [0.0001202964413096197] Val_RMS = [tensor(0.0110)] Val_NRMS = [tensor(0.0224)]
# epoch = 10000 Train_loss = [0.00011804678069893271] Val_loss = [0.0001175085490103811] Val_RMS = [tensor(0.0108)] Val_NRMS = [tensor(0.0221)]
# epoch = 15000 Train_loss = [0.0001172464617411606] Val_loss = [0.00011703302880050614] Val_RMS = [tensor(0.0108)] Val_NRMS = [tensor(0.0221)]
# epoch = 20000 Train_loss = [0.00011688802624121308] Val_loss = [0.0001167051013908349] Val_RMS = [tensor(0.0108)] Val_NRMS = [tensor(0.0221)]
# Testing training process:  23 (na = 3, nb = 8)
# epoch = 5000 Train_loss = [4.2265495721949264e-05] Val_loss = [4.6887624193914235e-05] Val_RMS = [tensor(0.0068)] Val_NRMS = [tensor(0.0140)]
# epoch = 10000 Train_loss = [2.0993682483094744e-05] Val_loss = [2.3495791538152844e-05] Val_RMS = [tensor(0.0048)] Val_NRMS = [tensor(0.0099)]
# epoch = 15000 Train_loss = [1.6695821614121087e-05] Val_loss = [1.847568819357548e-05] Val_RMS = [tensor(0.0043)] Val_NRMS = [tensor(0.0088)]
# epoch = 20000 Train_loss = [1.464143588236766e-05] Val_loss = [1.5936666386551224e-05] Val_RMS = [tensor(0.0040)] Val_NRMS = [tensor(0.0081)]
# Testing training process:  24 (na = 13, nb = 4)
# epoch = 5000 Train_loss = [3.069503145525232e-05] Val_loss = [3.4175933251390234e-05] Val_RMS = [tensor(0.0058)] Val_NRMS = [tensor(0.0119)]
# epoch = 10000 Train_loss = [1.3316944205143955e-05] Val_loss = [1.5101246390258893e-05] Val_RMS = [tensor(0.0039)] Val_NRMS = [tensor(0.0079)]
# epoch = 15000 Train_loss = [9.444565876037814e-06] Val_loss = [1.0912400284723844e-05] Val_RMS = [tensor(0.0033)] Val_NRMS = [tensor(0.0067)]
# epoch = 20000 Train_loss = [8.06601565273013e-06] Val_loss = [9.53182370722061e-06] Val_RMS = [tensor(0.0031)] Val_NRMS = [tensor(0.0063)]
# Testing training process:  25 (na = 9, nb = 4)
# epoch = 5000 Train_loss = [3.166091119055636e-05] Val_loss = [3.401564754312858e-05] Val_RMS = [tensor(0.0058)] Val_NRMS = [tensor(0.0118)]
# epoch = 10000 Train_loss = [1.4153692063700873e-05] Val_loss = [1.4780464880459476e-05] Val_RMS = [tensor(0.0038)] Val_NRMS = [tensor(0.0078)]
# epoch = 15000 Train_loss = [1.0769675100164022e-05] Val_loss = [1.0983820175169967e-05] Val_RMS = [tensor(0.0033)] Val_NRMS = [tensor(0.0067)]
# epoch = 20000 Train_loss = [9.458792192162946e-06] Val_loss = [9.617989235266577e-06] Val_RMS = [tensor(0.0031)] Val_NRMS = [tensor(0.0063)]
# Testing training process:  26 (na = 4, nb = 1)
# epoch = 5000 Train_loss = [4.6979814214864746e-05] Val_loss = [4.917016485705972e-05] Val_RMS = [tensor(0.0070)] Val_NRMS = [tensor(0.0143)]
# epoch = 10000 Train_loss = [4.011087730759755e-05] Val_loss = [4.280147186364047e-05] Val_RMS = [tensor(0.0065)] Val_NRMS = [tensor(0.0134)]
# epoch = 15000 Train_loss = [3.937908695661463e-05] Val_loss = [4.219198308419436e-05] Val_RMS = [tensor(0.0065)] Val_NRMS = [tensor(0.0133)]
# epoch = 20000 Train_loss = [3.910125087713823e-05] Val_loss = [4.193825225229375e-05] Val_RMS = [tensor(0.0065)] Val_NRMS = [tensor(0.0132)]
# Testing training process:  27 (na = 11, nb = 10)
# epoch = 5000 Train_loss = [2.221808426838834e-05] Val_loss = [2.7174717615707777e-05] Val_RMS = [tensor(0.0052)] Val_NRMS = [tensor(0.0106)]
# epoch = 10000 Train_loss = [8.375531251658686e-06] Val_loss = [1.0827374353539199e-05] Val_RMS = [tensor(0.0033)] Val_NRMS = [tensor(0.0067)]
# epoch = 15000 Train_loss = [6.672115887340624e-06] Val_loss = [8.984466148831416e-06] Val_RMS = [tensor(0.0030)] Val_NRMS = [tensor(0.0061)]
# epoch = 20000 Train_loss = [6.216838301043026e-06] Val_loss = [8.56331371323904e-06] Val_RMS = [tensor(0.0029)] Val_NRMS = [tensor(0.0060)]
# Testing training process:  28 (na = 5, nb = 1)
# epoch = 5000 Train_loss = [4.537424320005812e-05] Val_loss = [4.368752706795931e-05] Val_RMS = [tensor(0.0066)] Val_NRMS = [tensor(0.0134)]
# epoch = 10000 Train_loss = [3.8929716538405046e-05] Val_loss = [3.7160480133024976e-05] Val_RMS = [tensor(0.0061)] Val_NRMS = [tensor(0.0123)]
# epoch = 15000 Train_loss = [3.6584515328286216e-05] Val_loss = [3.440027649048716e-05] Val_RMS = [tensor(0.0059)] Val_NRMS = [tensor(0.0119)]
# epoch = 20000 Train_loss = [3.629700222518295e-05] Val_loss = [3.366369128343649e-05] Val_RMS = [tensor(0.0058)] Val_NRMS = [tensor(0.0117)]
# Testing training process:  29 (na = 5, nb = 7)
# epoch = 5000 Train_loss = [4.5582495658891276e-05] Val_loss = [5.315502858138643e-05] Val_RMS = [tensor(0.0073)] Val_NRMS = [tensor(0.0149)]
# epoch = 10000 Train_loss = [1.9131794033455662e-05] Val_loss = [2.1578025553026237e-05] Val_RMS = [tensor(0.0046)] Val_NRMS = [tensor(0.0095)]
# epoch = 15000 Train_loss = [1.4400509826373309e-05] Val_loss = [1.559168958920054e-05] Val_RMS = [tensor(0.0039)] Val_NRMS = [tensor(0.0081)]
# epoch = 20000 Train_loss = [1.1747752978408244e-05] Val_loss = [1.2366675946395844e-05] Val_RMS = [tensor(0.0035)] Val_NRMS = [tensor(0.0072)]

# %%
from pathlib import Path

# create folder
folder_name = 'ANN_tunning_3_layers'
p_model = (Path()/'Train'/folder_name)
p_model.mkdir(parents=True, exist_ok=True)

# save dataframe file
pd.DataFrame(loss).to_csv((p_model/f"loss.csv"))
pd.DataFrame(RMS).to_csv((p_model/f"RMS.csv"))
pd.DataFrame(NRMS).to_csv((p_model/f"NRMS.csv"))

# %%
plt.figure(figsize=(8, 9))
painted = 'loss'
for i in range(len(loss)):
    label = f'(na = {results[i][0]}, nb = {results[i][1]})'
    # if np.min(loss[i][19990:20000])<0.0002:
        # plt.plot(loss[i][19990:20000],label=label)
    plt.plot(loss[i],label=label)
plt.title(painted)
plt.ylabel(painted)
plt.xlabel('epoch')
plt.legend()
plt.show()

pic_name = f"loss_tunning.png"
plt.savefig((p_model/pic_name))

# %%
plt.figure(figsize=(8, 9))
painted = 'RMS'
for i in range(len(RMS)):
    label = f'(na = {results[i][0]}, nb = {results[i][1]})'
    # if np.min(RMS[i][19990:20000])<0.006:
        # plt.plot(RMS[i][19990:20000],label=label)
    plt.plot(RMS[i],label=label)
plt.title(painted)
plt.ylabel(painted)
plt.xlabel('epoch')
plt.legend()
plt.show()

pic_name = f"RMS_tunning.png"
plt.savefig((p_model/pic_name))

# %%
plt.figure(figsize=(8, 9))
painted = 'NRMS'
for i in range(len(NRMS)):
    label = f'(na = {results[i][0]}, nb = {results[i][1]})'
    # if np.min(NRMS[i][19990:20000])<0.01:
        # plt.plot(NRMS[i][19990:20000],label=label)
    plt.plot(NRMS[i],label=label)
plt.title(painted)
plt.ylabel(painted)
plt.xlabel('epoch')
plt.legend()
plt.show()

pic_name = f"NRMS_tunning.png"
plt.savefig((p_model/pic_name))
