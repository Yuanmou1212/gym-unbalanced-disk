# %% [markdown]
# ## Import libraries and load data

# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
import torch.nn as nn
import torch
import pandas as pd
import sys
from torch.utils.data import DataLoader

# %%
device="cuda" if torch.cuda.is_available() else "cpu"
print(device)

out = np.load('disc-benchmark-files/training-data.npz')
th_train = out['th'] #th[0],th[1],th[2],th[3],...
u_train = out['u'] #u[0],u[1],u[2],u[3],...

data = np.load('disc-benchmark-files/test-simulation-submission-file.npz')
u_test = data['u']
th_test = data['th'] #only the first 50 values are filled the rest are zeros
# Out:
# cuda

# %% [markdown]
# ## Visualize data

# %%
# Plotting the data
plt.figure(figsize=(20,4))
plt.subplot(1,2,1)
plt.plot(u_train,th_train,'.')
plt.xlabel('input (V)')
plt.ylabel('output (radians)')
plt.title('Training Data')
plt.subplot(1,2,2)
plt.plot(th_test,th_test,'.')
plt.xlabel('input (V)')
plt.ylabel('output (radians)')
plt.title('Test Data')
plt.show()

# %% [markdown]
# ## 1. ANN

# %%
def create_IO_data(u,y,na,nb):
    X = []
    Y = []
    for k in range(max(na,nb), len(y)):
        X.append(np.concatenate([u[k-nb:k],y[k-na:k]]))
        Y.append(y[k])
    return np.array(X), np.array(Y)

# %%
# class Network(nn.Module): 
#     def __init__(self, n_in, n_hidden_nodes): 
#         super(Network,self).__init__() 
#         self.lay1 = nn.Linear(n_in,n_hidden_nodes)
#         self.lay2 = nn.Linear(n_hidden_nodes,n_hidden_nodes)
#         self.lay3 = nn.Linear(n_hidden_nodes,1)
#     def forward(self,x): 
#         x1 = torch.relu(self.lay1(x))
#         x2 = torch.relu(self.lay2(x1))
#         y = self.lay3(x2)
#         return y 

class Network(nn.Module): 
    def __init__(self, n_in, n_hidden_nodes): 
        super(Network,self).__init__() 
        self.lay1 = nn.Linear(n_in,n_hidden_nodes)
        self.lay2 = nn.Linear(n_hidden_nodes,1)
    def forward(self,x): 
        x1 = torch.relu(self.lay1(x)) 
        y = self.lay2(x1)[:,0] 
        return y

# %%
def RMS_NRMS(y_pred, y_truth):
    y_pred = y_pred.detach().cpu()
    y_truth = y_truth.detach().cpu()
    RMS = (torch.mean((y_pred-y_truth)**2))**0.5
    NRMS = RMS/torch.std(y_truth)
    return RMS, NRMS

# %%
class Trainer:
    def __init__(self, model, data):
        self.device = "cuda" if torch.cuda.is_available() else "cpu"
        self.model = model.to(self.device)
        self.data = data

        self.optimizer = torch.optim.Adam(self.model.parameters(),lr=1e-4)
        self.critereon = nn.MSELoss()

        assert self.critereon is not None, "You have not defined a loss"
        assert self.optimizer is not None, "You have not defined an optimizer"


    def train_epoch(self, inputs, truths):
            # Put the model in training mode
            self.model.train()

            # Store each step's accuracy and loss for this epoch
            epoch_metrics = {
                "loss": [],
                "RMS": [],
                "NRMS": []
            }

            # Zero the gradients from the previous step
            self.optimizer.zero_grad()

            # Move the inputs and truths to the target device
            inputs = inputs.to(device=self.device)
            truths = truths.to(device=self.device)

            # Run model on the inputs
            output = self.model(inputs)
            
            # Perform backpropagation
            loss = self.critereon(output, truths)
            loss.backward()
            self.optimizer.step()

            # Store the metrics of this step
            step_metrics = {
                'loss': loss.item(),
                'RMS': RMS_NRMS(output, truths)[0],
                'NRMS': RMS_NRMS(output, truths)[1]
            }

            # Add to epoch's metrics
            for k,v in step_metrics.items():
                epoch_metrics[k].append(v)

            # Return metrics
            return epoch_metrics
    
    def val_epoch(self, inputs, truths):
        epoch_metrics = {
                "loss": [],
                "RMS": [],
                "NRMS": []
            }

        # Put the model in evaluation mode
        self.model.eval()
        with torch.no_grad():
            # Move the inputs and truths to the target device
            inputs = inputs.to(device=self.device, dtype=torch.float32)
            truths = truths.to(device=self.device, dtype=torch.float32)

            # Run model on the inputs
            output = self.model(inputs)
            loss = self.critereon(output, truths)

            # Store the metrics of this step
            step_metrics = {
                'loss': loss.item(),
                'RMS': RMS_NRMS(output, truths)[0],
                'NRMS': RMS_NRMS(output, truths)[1]
            }

            # Add to epoch's metrics
            for k,v in step_metrics.items():
                epoch_metrics[k].append(v)

        # Return metrics
        return epoch_metrics
    
    def fit(self, epochs: int):
        # Store metrics of the training process (plot this to gain insight)
        df_train = pd.DataFrame()
        df_val = pd.DataFrame()

        # Train the model for the provided amount of epochs
        for epoch in range(1, epochs+1):
            # print(f'Epoch {epoch}')
            
            metrics_train = self.train_epoch(self.data["Xtrain"],self.data["Ytrain"])
            df_train = pd.concat([df_train,pd.DataFrame({'epoch': [epoch for _ in range(len(metrics_train["loss"]))], **metrics_train})], ignore_index=True)
            
            metrics_val = self.val_epoch(self.data["Xval"],self.data["Yval"])
            df_val = pd.concat([df_val,pd.DataFrame({'epoch': [epoch for _ in range(len(metrics_val["loss"]))], **metrics_val})], ignore_index=True)
            # print(metrics_train["loss"])
            loss_train = metrics_train["loss"]
            loss_val = metrics_val["loss"]
            RMS_val = metrics_val["RMS"]
            NRMS_val = metrics_val["NRMS"]

            if (epoch + 1) % 5000 == 0:
                print('epoch =', epoch+1, 'Train_loss =',loss_train, 'Val_loss =', loss_val, 'Val_RMS =', RMS_val, 'Val_NRMS =', NRMS_val)
        
        # Return a dataframe that logs the training process. This can be exported to a CSV or plotted directly.
        return df_train, df_val
    

    '''mini batch'''
    # def fit(self, epochs: int, batch_size: int):
    #     df_train = pd.DataFrame()
    #     df_val = pd.DataFrame()
    #     num_samples = len(self.data["Xtrain"])
    #     num_batches = num_samples // batch_size

    #     for epoch in range(1, epochs+1):
    #         for batch in range(num_batches):
    #             start_idx = batch * batch_size
    #             end_idx = (batch + 1) * batch_size

    #             batch_X = self.data["Xtrain"][start_idx:end_idx]
    #             batch_Y = self.data["Ytrain"][start_idx:end_idx]

    #             metrics_train = self.train_epoch(batch_X, batch_Y)
    #             df_train = pd.concat([df_train, pd.DataFrame({'epoch': [epoch for _ in range(len(metrics_train["loss"]))], **metrics_train})], ignore_index=True)

    #             metrics_val = self.val_epoch(self.data["Xval"], self.data["Yval"])
    #             df_val = pd.concat([df_val, pd.DataFrame({'epoch': [epoch for _ in range(len(metrics_val["loss"]))], **metrics_val})], ignore_index=True)

    #             loss_train = metrics_train["loss"]
    #             loss_val = metrics_val["loss"]
    #             RMS_val = metrics_val["RMS"]
    #             NRMS_val = metrics_val["NRMS"]

    #         if (epoch + 1) % 2 == 0:
    #             print('epoch =', epoch+1, 'Train_loss =', loss_train, 'Val_loss =', loss_val, 'Val_RMS =', RMS_val, 'Val_NRMS =', NRMS_val)

    #     return df_train, df_val

# %% [markdown]
# ## tunning

# %%
import random

list1 = range(0, 15)
list2 = range(0, 15)
results = []

# using random layout near origin good selection
while len(results) < 30:
    # select randomly
    num1 = random.choice(list1)
    num2 = random.choice(list2)
    if num1==0 & num2==0:
        continue
    result = (num1, num2)
    
    # if it is not selected, add it
    if result not in results:
        results.append(result)

print(results)
# Out:
# [(3, 2), (11, 9), (7, 0), (9, 10), (14, 10), (5, 6), (3, 1), (10, 8), (14, 5), (8, 5), (10, 7), (11, 6), (8, 14), (4, 2), (14, 9), (8, 3), (4, 5), (8, 11), (9, 1), (4, 9), (11, 3), (3, 7), (4, 13), (12, 8), (1, 3), (10, 12), (8, 6), (13, 1), (13, 10), (6, 9)]

# %%
device="cuda" if torch.cuda.is_available() else "cpu"

loss = []
RMS = []
NRMS = []

for i in range(len(results)):
    val_RMS = []
    val_NRMS = []
    val_Loss = []
    na, nb = results[i]

    # generate data
    Xdata, Ydata = create_IO_data(u_train, th_train, na, nb)  # For training data
    Xtrain, Xval, Ytrain, Yval = train_test_split(Xdata,Ydata)
    Xtrain, Xval, Ytrain, Yval = [torch.as_tensor(x).to(device=device, dtype=torch.float32) for x in [Xtrain, Xval, Ytrain, Yval]]

    data = {
        "Xtrain": Xtrain,
        "Xval": Xval,
        "Ytrain": Ytrain,
        "Yval": Yval
    }

    # free memory
    torch.cuda.empty_cache()

    # Train the passthrough network
    print("Testing training process: ", i, f'(na = {results[i][0]}, nb = {results[i][1]})')
    model = Network(na + nb, n_hidden_nodes = 64)

    epochs = 20000
    trainer = Trainer(model, data)
    train_resluts, validation_results = trainer.fit(epochs=epochs)

    # save loss, RMS, NRMS
    painted = 'loss'
    for j in range(1,validation_results['epoch'].max()):
        val_Loss.append(validation_results[validation_results['epoch']==j][painted].mean(0))
    loss.append(val_Loss)
    
    painted = 'RMS'
    for i in range(1,validation_results['epoch'].max()):
        val_RMS.append(validation_results[validation_results['epoch']==i][painted].mean(0))
    RMS.append(val_RMS)

    painted = 'NRMS'
    for k in range(1,validation_results['epoch'].max()):
        val_NRMS.append(validation_results[validation_results['epoch']==k][painted].mean(0))
    NRMS.append(val_NRMS)
# Out:
# Testing training process:  0 (na = 3, nb = 2)
# epoch = 5000 Train_loss = [0.0002834551560226828] Val_loss = [0.0002785821270663291] Val_RMS = [tensor(0.0167)] Val_NRMS = [tensor(0.0339)]
# epoch = 10000 Train_loss = [7.106287375790998e-05] Val_loss = [7.019170152489096e-05] Val_RMS = [tensor(0.0084)] Val_NRMS = [tensor(0.0170)]
# epoch = 15000 Train_loss = [2.4355020286748186e-05] Val_loss = [2.334401142434217e-05] Val_RMS = [tensor(0.0048)] Val_NRMS = [tensor(0.0098)]
# epoch = 20000 Train_loss = [1.8917176930699497e-05] Val_loss = [1.7624650354264304e-05] Val_RMS = [tensor(0.0042)] Val_NRMS = [tensor(0.0085)]
# Testing training process:  1 (na = 11, nb = 9)
# epoch = 5000 Train_loss = [0.0007171972538344562] Val_loss = [0.0007368978695012629] Val_RMS = [tensor(0.0271)] Val_NRMS = [tensor(0.0552)]
# epoch = 10000 Train_loss = [6.1025606555631384e-05] Val_loss = [6.712115282425657e-05] Val_RMS = [tensor(0.0082)] Val_NRMS = [tensor(0.0167)]
# epoch = 15000 Train_loss = [1.155121935880743e-05] Val_loss = [1.4186768567014951e-05] Val_RMS = [tensor(0.0038)] Val_NRMS = [tensor(0.0077)]
# epoch = 20000 Train_loss = [8.98854614206357e-06] Val_loss = [1.1105566045443993e-05] Val_RMS = [tensor(0.0033)] Val_NRMS = [tensor(0.0068)]
# Testing training process:  2 (na = 7, nb = 0)
# epoch = 5000 Train_loss = [0.0018756994977593422] Val_loss = [0.001885343692265451] Val_RMS = [tensor(0.0434)] Val_NRMS = [tensor(0.0875)]
# epoch = 10000 Train_loss = [0.0004434192960616201] Val_loss = [0.00043551946873776615] Val_RMS = [tensor(0.0209)] Val_NRMS = [tensor(0.0421)]
# epoch = 15000 Train_loss = [0.0002570368815213442] Val_loss = [0.0002484399301465601] Val_RMS = [tensor(0.0158)] Val_NRMS = [tensor(0.0318)]
# epoch = 20000 Train_loss = [0.0002388628345215693] Val_loss = [0.00022875997819937766] Val_RMS = [tensor(0.0151)] Val_NRMS = [tensor(0.0305)]
# Testing training process:  3 (na = 9, nb = 10)
# epoch = 5000 Train_loss = [0.0009189192787744105] Val_loss = [0.0009155792649835348] Val_RMS = [tensor(0.0303)] Val_NRMS = [tensor(0.0614)]
# epoch = 10000 Train_loss = [7.980635564308614e-05] Val_loss = [9.125595533987507e-05] Val_RMS = [tensor(0.0096)] Val_NRMS = [tensor(0.0194)]
# epoch = 15000 Train_loss = [1.4826860024186317e-05] Val_loss = [1.6747859262977727e-05] Val_RMS = [tensor(0.0041)] Val_NRMS = [tensor(0.0083)]
# epoch = 20000 Train_loss = [1.0339294021832757e-05] Val_loss = [1.16845303637092e-05] Val_RMS = [tensor(0.0034)] Val_NRMS = [tensor(0.0069)]
# Testing training process:  4 (na = 14, nb = 10)
# epoch = 5000 Train_loss = [0.0007565662963315845] Val_loss = [0.0007520908839069307] Val_RMS = [tensor(0.0274)] Val_NRMS = [tensor(0.0555)]
# epoch = 10000 Train_loss = [5.579368371400051e-05] Val_loss = [5.633135879179463e-05] Val_RMS = [tensor(0.0075)] Val_NRMS = [tensor(0.0152)]
# epoch = 15000 Train_loss = [1.4023358744452707e-05] Val_loss = [1.468489153921837e-05] Val_RMS = [tensor(0.0038)] Val_NRMS = [tensor(0.0078)]
# epoch = 20000 Train_loss = [8.883655937097501e-06] Val_loss = [9.575870535627473e-06] Val_RMS = [tensor(0.0031)] Val_NRMS = [tensor(0.0063)]
# Testing training process:  5 (na = 5, nb = 6)
# epoch = 5000 Train_loss = [0.00045477820094674826] Val_loss = [0.0004934594035148621] Val_RMS = [tensor(0.0222)] Val_NRMS = [tensor(0.0456)]
# epoch = 10000 Train_loss = [5.412876635091379e-05] Val_loss = [6.248427234822884e-05] Val_RMS = [tensor(0.0079)] Val_NRMS = [tensor(0.0162)]
# epoch = 15000 Train_loss = [1.1738598004740197e-05] Val_loss = [1.2916623745695688e-05] Val_RMS = [tensor(0.0036)] Val_NRMS = [tensor(0.0074)]
# epoch = 20000 Train_loss = [9.477539606450591e-06] Val_loss = [1.0228527571598534e-05] Val_RMS = [tensor(0.0032)] Val_NRMS = [tensor(0.0066)]
# Testing training process:  6 (na = 3, nb = 1)
# epoch = 5000 Train_loss = [0.0005185805493965745] Val_loss = [0.0005399452056735754] Val_RMS = [tensor(0.0232)] Val_NRMS = [tensor(0.0472)]
# epoch = 10000 Train_loss = [0.00014185282634571195] Val_loss = [0.00014541420387104154] Val_RMS = [tensor(0.0121)] Val_NRMS = [tensor(0.0245)]
# epoch = 15000 Train_loss = [4.3340944102965295e-05] Val_loss = [4.272840669727884e-05] Val_RMS = [tensor(0.0065)] Val_NRMS = [tensor(0.0133)]
# epoch = 20000 Train_loss = [4.147804429521784e-05] Val_loss = [4.085178443347104e-05] Val_RMS = [tensor(0.0064)] Val_NRMS = [tensor(0.0130)]
# Testing training process:  7 (na = 10, nb = 8)
# epoch = 5000 Train_loss = [0.0008385204710066319] Val_loss = [0.0008968468173407018] Val_RMS = [tensor(0.0299)] Val_NRMS = [tensor(0.0614)]
# epoch = 10000 Train_loss = [9.404641605215147e-05] Val_loss = [9.913890244206414e-05] Val_RMS = [tensor(0.0100)] Val_NRMS = [tensor(0.0204)]
# epoch = 15000 Train_loss = [1.4515956536342856e-05] Val_loss = [1.4877526155032683e-05] Val_RMS = [tensor(0.0039)] Val_NRMS = [tensor(0.0079)]
# epoch = 20000 Train_loss = [8.428115506831091e-06] Val_loss = [8.799960596661549e-06] Val_RMS = [tensor(0.0030)] Val_NRMS = [tensor(0.0061)]
# Testing training process:  8 (na = 14, nb = 5)
# epoch = 5000 Train_loss = [0.0005073877982795238] Val_loss = [0.0005852529429830611] Val_RMS = [tensor(0.0242)] Val_NRMS = [tensor(0.0489)]
# epoch = 10000 Train_loss = [5.569540007854812e-05] Val_loss = [6.648620910709724e-05] Val_RMS = [tensor(0.0082)] Val_NRMS = [tensor(0.0165)]
# epoch = 15000 Train_loss = [1.28519932331983e-05] Val_loss = [1.649928162805736e-05] Val_RMS = [tensor(0.0041)] Val_NRMS = [tensor(0.0082)]
# epoch = 20000 Train_loss = [9.211988071911037e-06] Val_loss = [1.066812274075346e-05] Val_RMS = [tensor(0.0033)] Val_NRMS = [tensor(0.0066)]
# Testing training process:  9 (na = 8, nb = 5)
# epoch = 5000 Train_loss = [0.0006803905125707388] Val_loss = [0.0007272228831425309] Val_RMS = [tensor(0.0270)] Val_NRMS = [tensor(0.0548)]
# epoch = 10000 Train_loss = [0.00010977960482705384] Val_loss = [0.00011809206625912338] Val_RMS = [tensor(0.0109)] Val_NRMS = [tensor(0.0221)]
# epoch = 15000 Train_loss = [1.8260188880958594e-05] Val_loss = [1.886299651232548e-05] Val_RMS = [tensor(0.0043)] Val_NRMS = [tensor(0.0088)]
# epoch = 20000 Train_loss = [1.101655016100267e-05] Val_loss = [1.1178967724845279e-05] Val_RMS = [tensor(0.0033)] Val_NRMS = [tensor(0.0068)]
# Testing training process:  10 (na = 10, nb = 7)
# epoch = 5000 Train_loss = [0.0007058102055452764] Val_loss = [0.0007008432294242084] Val_RMS = [tensor(0.0265)] Val_NRMS = [tensor(0.0538)]
# epoch = 10000 Train_loss = [6.643947563134134e-05] Val_loss = [7.034134614514187e-05] Val_RMS = [tensor(0.0084)] Val_NRMS = [tensor(0.0171)]
# epoch = 15000 Train_loss = [1.3735799257119652e-05] Val_loss = [1.4755356460227631e-05] Val_RMS = [tensor(0.0038)] Val_NRMS = [tensor(0.0078)]
# epoch = 20000 Train_loss = [1.0522306183702312e-05] Val_loss = [1.1449325029389001e-05] Val_RMS = [tensor(0.0034)] Val_NRMS = [tensor(0.0069)]
# Testing training process:  11 (na = 11, nb = 6)
# epoch = 5000 Train_loss = [0.00043154542800039053] Val_loss = [0.00042469496838748455] Val_RMS = [tensor(0.0206)] Val_NRMS = [tensor(0.0417)]
# epoch = 10000 Train_loss = [5.148765922058374e-05] Val_loss = [5.0896196626126766e-05] Val_RMS = [tensor(0.0071)] Val_NRMS = [tensor(0.0144)]
# epoch = 15000 Train_loss = [1.2154351679782849e-05] Val_loss = [1.1311443813610822e-05] Val_RMS = [tensor(0.0034)] Val_NRMS = [tensor(0.0068)]
# epoch = 20000 Train_loss = [9.740094355947804e-06] Val_loss = [8.727406566322315e-06] Val_RMS = [tensor(0.0030)] Val_NRMS = [tensor(0.0060)]
# Testing training process:  12 (na = 8, nb = 14)
# epoch = 5000 Train_loss = [0.0013076327741146088] Val_loss = [0.0012826515594497323] Val_RMS = [tensor(0.0358)] Val_NRMS = [tensor(0.0730)]
# epoch = 10000 Train_loss = [0.00013493576261680573] Val_loss = [0.00013224173744674772] Val_RMS = [tensor(0.0115)] Val_NRMS = [tensor(0.0234)]
# epoch = 15000 Train_loss = [1.3881637642043643e-05] Val_loss = [1.414027519786032e-05] Val_RMS = [tensor(0.0038)] Val_NRMS = [tensor(0.0077)]
# epoch = 20000 Train_loss = [1.066637287294725e-05] Val_loss = [1.0962396117975004e-05] Val_RMS = [tensor(0.0033)] Val_NRMS = [tensor(0.0068)]
# Testing training process:  13 (na = 4, nb = 2)
# epoch = 5000 Train_loss = [0.0006897423299960792] Val_loss = [0.0006810391787439585] Val_RMS = [tensor(0.0261)] Val_NRMS = [tensor(0.0536)]
# epoch = 10000 Train_loss = [0.00011521336273290217] Val_loss = [0.000117426723591052] Val_RMS = [tensor(0.0108)] Val_NRMS = [tensor(0.0222)]
# epoch = 15000 Train_loss = [1.985168273677118e-05] Val_loss = [2.2188283764990047e-05] Val_RMS = [tensor(0.0047)] Val_NRMS = [tensor(0.0097)]
# epoch = 20000 Train_loss = [1.4185291547619272e-05] Val_loss = [1.60143717948813e-05] Val_RMS = [tensor(0.0040)] Val_NRMS = [tensor(0.0082)]
# Testing training process:  14 (na = 14, nb = 9)
# epoch = 5000 Train_loss = [0.0006665189866907895] Val_loss = [0.0006286597927100956] Val_RMS = [tensor(0.0251)] Val_NRMS = [tensor(0.0514)]
# epoch = 10000 Train_loss = [4.499345232034102e-05] Val_loss = [4.4585776777239516e-05] Val_RMS = [tensor(0.0067)] Val_NRMS = [tensor(0.0137)]
# epoch = 15000 Train_loss = [1.332366718997946e-05] Val_loss = [1.422973582521081e-05] Val_RMS = [tensor(0.0038)] Val_NRMS = [tensor(0.0077)]
# epoch = 20000 Train_loss = [8.608577445556875e-06] Val_loss = [9.103593583859038e-06] Val_RMS = [tensor(0.0030)] Val_NRMS = [tensor(0.0062)]
# Testing training process:  15 (na = 8, nb = 3)
# epoch = 5000 Train_loss = [0.0005635516718029976] Val_loss = [0.000565439579077065] Val_RMS = [tensor(0.0238)] Val_NRMS = [tensor(0.0484)]
# epoch = 10000 Train_loss = [7.11730244802311e-05] Val_loss = [7.247592293424532e-05] Val_RMS = [tensor(0.0085)] Val_NRMS = [tensor(0.0173)]
# epoch = 15000 Train_loss = [1.770427479641512e-05] Val_loss = [1.7595406461623497e-05] Val_RMS = [tensor(0.0042)] Val_NRMS = [tensor(0.0085)]
# epoch = 20000 Train_loss = [1.0650909644027706e-05] Val_loss = [1.0350483535148669e-05] Val_RMS = [tensor(0.0032)] Val_NRMS = [tensor(0.0065)]
# Testing training process:  16 (na = 4, nb = 5)
# epoch = 5000 Train_loss = [0.0005684146890416741] Val_loss = [0.0005799716454930604] Val_RMS = [tensor(0.0241)] Val_NRMS = [tensor(0.0485)]
# epoch = 10000 Train_loss = [0.00011677913425955921] Val_loss = [0.00012476110714487731] Val_RMS = [tensor(0.0112)] Val_NRMS = [tensor(0.0225)]
# epoch = 15000 Train_loss = [2.655840216903016e-05] Val_loss = [2.8327660402283072e-05] Val_RMS = [tensor(0.0053)] Val_NRMS = [tensor(0.0107)]
# epoch = 20000 Train_loss = [1.5768187950016e-05] Val_loss = [1.5933332178974524e-05] Val_RMS = [tensor(0.0040)] Val_NRMS = [tensor(0.0080)]
# Testing training process:  17 (na = 8, nb = 11)
# epoch = 5000 Train_loss = [0.0012486906489357352] Val_loss = [0.001219143159687519] Val_RMS = [tensor(0.0349)] Val_NRMS = [tensor(0.0710)]
# epoch = 10000 Train_loss = [0.00018532334070187062] Val_loss = [0.00017697773000691086] Val_RMS = [tensor(0.0133)] Val_NRMS = [tensor(0.0271)]
# epoch = 15000 Train_loss = [1.3727275472774636e-05] Val_loss = [1.3171352293284144e-05] Val_RMS = [tensor(0.0036)] Val_NRMS = [tensor(0.0074)]
# epoch = 20000 Train_loss = [9.90408989309799e-06] Val_loss = [9.566258995619137e-06] Val_RMS = [tensor(0.0031)] Val_NRMS = [tensor(0.0063)]
# Testing training process:  18 (na = 9, nb = 1)
# epoch = 5000 Train_loss = [0.0005180860171094537] Val_loss = [0.0005077124224044383] Val_RMS = [tensor(0.0225)] Val_NRMS = [tensor(0.0463)]
# epoch = 10000 Train_loss = [6.913745892234147e-05] Val_loss = [7.546330743934959e-05] Val_RMS = [tensor(0.0087)] Val_NRMS = [tensor(0.0178)]
# epoch = 15000 Train_loss = [3.9284772356040776e-05] Val_loss = [4.788682781509124e-05] Val_RMS = [tensor(0.0069)] Val_NRMS = [tensor(0.0142)]
# epoch = 20000 Train_loss = [3.511977774905972e-05] Val_loss = [4.4413154682843015e-05] Val_RMS = [tensor(0.0067)] Val_NRMS = [tensor(0.0137)]
# Testing training process:  19 (na = 4, nb = 9)
# epoch = 5000 Train_loss = [0.0008184717735275626] Val_loss = [0.0008516288944520056] Val_RMS = [tensor(0.0292)] Val_NRMS = [tensor(0.0594)]
# epoch = 10000 Train_loss = [0.00012394168879836798] Val_loss = [0.00013208283053245395] Val_RMS = [tensor(0.0115)] Val_NRMS = [tensor(0.0234)]
# epoch = 15000 Train_loss = [2.574101927166339e-05] Val_loss = [2.5923591238097288e-05] Val_RMS = [tensor(0.0051)] Val_NRMS = [tensor(0.0104)]
# epoch = 20000 Train_loss = [1.5906329281278886e-05] Val_loss = [1.598019116499927e-05] Val_RMS = [tensor(0.0040)] Val_NRMS = [tensor(0.0081)]
# Testing training process:  20 (na = 11, nb = 3)
# epoch = 5000 Train_loss = [0.0005482857814058661] Val_loss = [0.000549621123354882] Val_RMS = [tensor(0.0234)] Val_NRMS = [tensor(0.0475)]
# epoch = 10000 Train_loss = [7.652926433365792e-05] Val_loss = [7.9919962445274e-05] Val_RMS = [tensor(0.0089)] Val_NRMS = [tensor(0.0181)]
# epoch = 15000 Train_loss = [1.5071822417667136e-05] Val_loss = [1.6026657249312848e-05] Val_RMS = [tensor(0.0040)] Val_NRMS = [tensor(0.0081)]
# epoch = 20000 Train_loss = [1.0457920325279702e-05] Val_loss = [1.0983738320646808e-05] Val_RMS = [tensor(0.0033)] Val_NRMS = [tensor(0.0067)]
# Testing training process:  21 (na = 3, nb = 7)
# epoch = 5000 Train_loss = [0.0007494409219361842] Val_loss = [0.0007785912021063268] Val_RMS = [tensor(0.0279)] Val_NRMS = [tensor(0.0567)]
# epoch = 10000 Train_loss = [0.00014934036880731583] Val_loss = [0.00017057916556950659] Val_RMS = [tensor(0.0131)] Val_NRMS = [tensor(0.0265)]
# epoch = 15000 Train_loss = [2.194565058744047e-05] Val_loss = [2.632869473018218e-05] Val_RMS = [tensor(0.0051)] Val_NRMS = [tensor(0.0104)]
# epoch = 20000 Train_loss = [1.1080232070526108e-05] Val_loss = [1.2290828635741491e-05] Val_RMS = [tensor(0.0035)] Val_NRMS = [tensor(0.0071)]
# Testing training process:  22 (na = 4, nb = 13)
# epoch = 5000 Train_loss = [0.0010629361495375633] Val_loss = [0.0011211192468181252] Val_RMS = [tensor(0.0335)] Val_NRMS = [tensor(0.0684)]
# epoch = 10000 Train_loss = [0.00014828756684437394] Val_loss = [0.00017217746062669903] Val_RMS = [tensor(0.0131)] Val_NRMS = [tensor(0.0268)]
# epoch = 15000 Train_loss = [2.5941637431969866e-05] Val_loss = [3.061318784602918e-05] Val_RMS = [tensor(0.0055)] Val_NRMS = [tensor(0.0113)]
# epoch = 20000 Train_loss = [1.385481209581485e-05] Val_loss = [1.661534588492941e-05] Val_RMS = [tensor(0.0041)] Val_NRMS = [tensor(0.0083)]
# Testing training process:  23 (na = 12, nb = 8)
# epoch = 5000 Train_loss = [0.000601125240791589] Val_loss = [0.0006334488862194121] Val_RMS = [tensor(0.0252)] Val_NRMS = [tensor(0.0514)]
# epoch = 10000 Train_loss = [4.9743055569706485e-05] Val_loss = [5.6944340030895546e-05] Val_RMS = [tensor(0.0075)] Val_NRMS = [tensor(0.0154)]
# epoch = 15000 Train_loss = [1.116781095333863e-05] Val_loss = [1.3135695553501137e-05] Val_RMS = [tensor(0.0036)] Val_NRMS = [tensor(0.0074)]
# epoch = 20000 Train_loss = [9.312324436905328e-06] Val_loss = [1.0865676813409664e-05] Val_RMS = [tensor(0.0033)] Val_NRMS = [tensor(0.0067)]
# Testing training process:  24 (na = 1, nb = 3)
# epoch = 5000 Train_loss = [0.012496205978095531] Val_loss = [0.0123977642506361] Val_RMS = [tensor(0.1113)] Val_NRMS = [tensor(0.2263)]
# epoch = 10000 Train_loss = [0.012200760655105114] Val_loss = [0.012108288705348969] Val_RMS = [tensor(0.1100)] Val_NRMS = [tensor(0.2236)]
# epoch = 15000 Train_loss = [0.012135148979723454] Val_loss = [0.01207780372351408] Val_RMS = [tensor(0.1099)] Val_NRMS = [tensor(0.2233)]
# epoch = 20000 Train_loss = [0.012123885564506054] Val_loss = [0.012082530185580254] Val_RMS = [tensor(0.1099)] Val_NRMS = [tensor(0.2234)]
# Testing training process:  25 (na = 10, nb = 12)
# epoch = 5000 Train_loss = [0.001147843082435429] Val_loss = [0.001302623306401074] Val_RMS = [tensor(0.0361)] Val_NRMS = [tensor(0.0733)]
# epoch = 10000 Train_loss = [6.766524165868759e-05] Val_loss = [7.982857641763985e-05] Val_RMS = [tensor(0.0089)] Val_NRMS = [tensor(0.0182)]
# epoch = 15000 Train_loss = [1.3981933079776354e-05] Val_loss = [1.684243034105748e-05] Val_RMS = [tensor(0.0041)] Val_NRMS = [tensor(0.0083)]
# epoch = 20000 Train_loss = [1.1483261005196255e-05] Val_loss = [1.3902945283916779e-05] Val_RMS = [tensor(0.0037)] Val_NRMS = [tensor(0.0076)]
# Testing training process:  26 (na = 8, nb = 6)
# epoch = 5000 Train_loss = [0.0007062007207423449] Val_loss = [0.0006779522518627346] Val_RMS = [tensor(0.0260)] Val_NRMS = [tensor(0.0528)]
# epoch = 10000 Train_loss = [0.00011867310240631923] Val_loss = [0.00013113742170389742] Val_RMS = [tensor(0.0115)] Val_NRMS = [tensor(0.0232)]
# epoch = 15000 Train_loss = [1.2195645467727445e-05] Val_loss = [1.4153178199194372e-05] Val_RMS = [tensor(0.0038)] Val_NRMS = [tensor(0.0076)]
# epoch = 20000 Train_loss = [9.955770110536832e-06] Val_loss = [1.1801923392340541e-05] Val_RMS = [tensor(0.0034)] Val_NRMS = [tensor(0.0070)]
# Testing training process:  27 (na = 13, nb = 1)
# epoch = 5000 Train_loss = [0.0010780610609799623] Val_loss = [0.0010923461522907019] Val_RMS = [tensor(0.0331)] Val_NRMS = [tensor(0.0676)]
# epoch = 10000 Train_loss = [0.00011356861068634316] Val_loss = [0.00011667715443763882] Val_RMS = [tensor(0.0108)] Val_NRMS = [tensor(0.0221)]
# epoch = 15000 Train_loss = [4.382289989735e-05] Val_loss = [4.600522879627533e-05] Val_RMS = [tensor(0.0068)] Val_NRMS = [tensor(0.0139)]
# epoch = 20000 Train_loss = [3.6432269553188235e-05] Val_loss = [3.868121712002903e-05] Val_RMS = [tensor(0.0062)] Val_NRMS = [tensor(0.0127)]
# Testing training process:  28 (na = 13, nb = 10)
# epoch = 5000 Train_loss = [0.0008615005644969642] Val_loss = [0.0008903240668587387] Val_RMS = [tensor(0.0298)] Val_NRMS = [tensor(0.0605)]
# epoch = 10000 Train_loss = [7.659917901037261e-05] Val_loss = [8.740420162212104e-05] Val_RMS = [tensor(0.0093)] Val_NRMS = [tensor(0.0190)]
# epoch = 15000 Train_loss = [1.4956256563891657e-05] Val_loss = [1.670483106863685e-05] Val_RMS = [tensor(0.0041)] Val_NRMS = [tensor(0.0083)]
# epoch = 20000 Train_loss = [1.1819648534583393e-05] Val_loss = [1.3330417459656019e-05] Val_RMS = [tensor(0.0037)] Val_NRMS = [tensor(0.0074)]
# Testing training process:  29 (na = 6, nb = 9)
# epoch = 5000 Train_loss = [0.0010775454575195909] Val_loss = [0.0011187795316800475] Val_RMS = [tensor(0.0334)] Val_NRMS = [tensor(0.0678)]
# epoch = 10000 Train_loss = [0.00019298410916235298] Val_loss = [0.00020537480304483324] Val_RMS = [tensor(0.0143)] Val_NRMS = [tensor(0.0290)]
# epoch = 15000 Train_loss = [2.0021130694658495e-05] Val_loss = [2.133793168468401e-05] Val_RMS = [tensor(0.0046)] Val_NRMS = [tensor(0.0094)]
# epoch = 20000 Train_loss = [1.082385097106453e-05] Val_loss = [1.174785847979365e-05] Val_RMS = [tensor(0.0034)] Val_NRMS = [tensor(0.0069)]

# %%
from pathlib import Path

# create folder
folder_name = 'ANN_tunning_1_layer'
p_model = (Path()/'Train'/folder_name)
p_model.mkdir(parents=True, exist_ok=True)

# save dataframe file
pd.DataFrame(loss).to_csv((p_model/f"loss.csv"))
pd.DataFrame(RMS).to_csv((p_model/f"RMS.csv"))
pd.DataFrame(NRMS).to_csv((p_model/f"NRMS.csv"))

# %%
plt.figure(figsize=(8, 10))
painted = 'loss'
for i in range(len(loss)):
    label = f'(na = {results[i][0]}, nb = {results[i][1]})'
    # if np.min(loss[i][19990:20000])<0.0002:
    #     plt.plot(loss[i][19990:20000],label=label)
    plt.plot(loss[i],label=label)
plt.title(painted)
plt.ylabel(painted)
plt.xlabel('epoch')
plt.legend()
plt.show()

pic_name = f"loss_tunning.png"
plt.savefig((p_model/pic_name))

# %%
plt.figure(figsize=(8, 10))
painted = 'RMS'
for i in range(len(RMS)):
    label = f'(na = {results[i][0]}, nb = {results[i][1]})'
    # if np.min(RMS[i][19990:20000])<0.006:
    #     plt.plot(RMS[i][19990:20000],label=label)
    plt.plot(RMS[i],label=label)
plt.title(painted)
plt.ylabel(painted)
plt.xlabel('epoch')
plt.legend()
plt.show()

pic_name = f"RMS_tunning.png"
plt.savefig((p_model/pic_name))

# %%
plt.figure(figsize=(8,10))
painted = 'NRMS'
for i in range(len(NRMS)):
    label = f'(na = {results[i][0]}, nb = {results[i][1]})'
    # if np.min(NRMS[i][19990:20000])<0.01:
    #     plt.plot(NRMS[i][19990:20000],label=label)
    plt.plot(NRMS[i],label=label)
plt.title(painted)
plt.ylabel(painted)
plt.xlabel('epoch')
plt.legend()
plt.show()

pic_name = f"NRMS_tunning.png"
plt.savefig((p_model/pic_name))
